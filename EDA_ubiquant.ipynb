# %%
dir_path = "/content/drive/MyDrive/Kaggle/UbiquantMarketPredictionDrive/zume/"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Kaggle/UbiquantMarketPredictionDrive/zume/
# %env TOKEN=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
# !git clone https://$$TOKEN@github.com/hzume/ubiquant_src.git
# Out:
# /content/drive/MyDrive/Kaggle/UbiquantMarketPredictionDrive/zume
# env: TOKEN=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
# Cloning into 'ubiquant_src'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_parquet(dir_path + "/Dataset/ubiquant-parquet/train_low_mem.parquet")

# %%
# columns:
#   row_id
#   time_id
#   investment_id
#   target
#   f_0 ~ f_299

# %%
train_0 = train.astype({f"f_{i}" : np.float16 for i in range(300)})
